# %%
print("Intro to Pyhton programming")
# Out:
# Intro to Pyhton programming

# %%
Python Vriables

# %%
a = 10
b = 20
c = a+b
print(c)
# Out:
# 30

# %%
Intro to data types in python

strings --> str
numbers --> int , float
list --> list
tuples --> tuple
dictionaries --> dict

python is a case sensitive

# %%
classification of data types
mutable datatype --> can be changable --> flexable nature 
immutable --> cannot be changable --> fixed in nature
Intro to stirgs
define strings by
. single quote
. double quotes

# %%
name1 = 'Ravi'
name2 = "Ramu"
print(name1)
print(name2)
# Out:
# Ravi
# Ramu
